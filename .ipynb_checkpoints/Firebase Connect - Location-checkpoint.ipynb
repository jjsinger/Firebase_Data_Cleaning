# %% [markdown]
# ### Configuration

# %%
#pyrebase

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the 'C:\Users\Snowbird\Envs\firebase\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pyrebase
import json
import pandas as pd
import numpy as np
config = {
    "apiKey": "AIzaSyClvaq9O3cpzeVaBwoltdM2cgdUaqhkb8w",
    "authDomain": "authtest-caf38.firebaseapp.com",
    "databaseURL": "https://authtest-caf38-default-rtdb.firebaseio.com",
    "projectId": "authtest-caf38",
    "storageBucket": "authtest-caf38.appspot.com",
    "messagingSenderId": "357691121267",
    "appId": "1:357691121267:web:7ec814b9b549e0d0fd5406"
  }

# %% [markdown]
# ### Initialize app and Create DB instance

# %%
firebase = pyrebase.initialize_app(config)

# %%
db = firebase.database()

# %%
orders = db.child("orders").get()
print(json.dumps(orders.val(),sort_keys=True, indent=4))
# Out:
# {
#     "-MW_pM0pEch3dDoHZG0Q": {
#         "orl6bgSZGJX9pDbJnfxnmWTsoZ4F": {
#             "created_at": "2021-03-24T20:03:08.903Z",
#             "customer_id": "123",
#             "id": "orl6bgSZGJX9pDbJnfxnmWTsoZ4F",
#             "line_items": [
#                 {
#                     "base_price_money": {
#                         "amount": 5000,
#                         "currency": "USD"
#                     },
#                     "catalog_object_id": "ZY24LSNTPTV3MK5U5NZRBI6S",
#                     "gross_sales_money": {
#                         "amount": 5000,
#                         "currency": "USD"
#                     },
#                     "name": "Cheese Sauce",
#                     "quantity": "1",
#                     "total_discount_money": {
#                         "amount": 0,
#                         "currency": "USD"
#                     },
#                     "total_money": {
#                         "amount": 5000,
# ...

# %%
# "created_at", "customer_id", "id", "line_items"

# orders_json = json.dumps(orders.val())
# df = pd.read_json(orders_json)

# %% [markdown]
#  ### Cleaning

# %%
orders.val()
# Out:
# OrderedDict([('-MW_pM0pEch3dDoHZG0Q',
#               {'orl6bgSZGJX9pDbJnfxnmWTsoZ4F': {'created_at': '2021-03-24T20:03:08.903Z',
#                 'customer_id': '123',
#                 'id': 'orl6bgSZGJX9pDbJnfxnmWTsoZ4F',
#                 'line_items': [{'base_price_money': {'amount': 5000,
#                    'currency': 'USD'},
#                   'catalog_object_id': 'ZY24LSNTPTV3MK5U5NZRBI6S',
#                   'gross_sales_money': {'amount': 5000, 'currency': 'USD'},
#                   'name': 'Cheese Sauce',
#                   'quantity': '1',
#                   'total_discount_money': {'amount': 0, 'currency': 'USD'},
#                   'total_money': {'amount': 5000, 'currency': 'USD'},
#                   'total_tax_money': {'amount': 0, 'currency': 'USD'},
#                   'uid': 'Dd2qIqJyRa8UZf5fisE7DC',
#                   'variation_name': 'Regular',
#                   'variation_total_price_money': {'amount': 5000,
# ...

# %%
orders_dict = pd.DataFrame(orders.val())

# %%
columns_old = orders_dict.columns

# %%
columns_ls = ['-MW_pM0pEch3dDoHZG0Q', '-MW_pQf_FsTiUj8o47Hp', '-MW_pTcdKVnoIblt0inx',
       '-MW_pgsFWmAFqvBYNKGz', '-MWbeV0FYiuufU2SNAxH', '-MWdi97_Mo4ACk1d4w0s',
       '-MWfkiau2GOEdj4F8RlM', '-MWg6OXOqVdyJeToxZkE', '-MWgAqBsMj513GCEXhiN',
       '-MWgAu7aS8s9yFDjPwTk', '-MWgBCnBhS2Tb4uaItnO', '-MWiy7GGm5W_wgmahE9R',
       '-MWoJxY22NJsCGvWZIPB', '-MWoNbGR6hrApSfWSxu7', '-MWobvsyCCpA8bYtohfP',
       '-MWocOf4orEE7T77_j4L', '-MWofMYIjR9gZEv30bVo', '-MWofSWHv-xZ0nq-klVV',
       '-MWofXvLxWSVokzuUlaN', '-MWoft6sh9KtvysiT6gB', '-MWoibCLwjA89rxrYbRb',
       '-MWqqYk3eRUZqhxcF9it', '-MWqrlPRDE_0Quy9XExb', '-MWzB8SVMYrL4IeJx8kc']

# %%
columns_new = [x[1:] for x in columns_ls if x[0] == "-"]

# %%
# Show first 5 columns that have been changed
columns_new[0:5]
# Out:
# ['MW_pM0pEch3dDoHZG0Q',
#  'MW_pQf_FsTiUj8o47Hp',
#  'MW_pTcdKVnoIblt0inx',
#  'MW_pgsFWmAFqvBYNKGz',
#  'MWbeV0FYiuufU2SNAxH']

# %%
orders_dict.columns = columns_new
orders_dict.columns

# %%
orders_dict
# Out:
#                                                             MW_pM0pEch3dDoHZG0Q  \
# orl6bgSZGJX9pDbJnfxnmWTsoZ4F  {'created_at': '2021-03-24T20:03:08.903Z', 'cu...
# order                         {'created_at': '2021-03-24T20:03:08.903Z', 'cu...
#
#                                                             MW_pQf_FsTiUj8o47Hp  \
# orl6bgSZGJX9pDbJnfxnmWTsoZ4F                                                NaN
# order                         {'created_at': '2021-03-24T20:03:28.569Z', 'cu...
#
#                                                             MW_pTcdKVnoIblt0inx  \
# orl6bgSZGJX9pDbJnfxnmWTsoZ4F                                                NaN
# order                         {'created_at': '2021-03-24T20:03:41.023Z', 'cu...
#
#                                                             MW_pgsFWmAFqvBYNKGz  \
# orl6bgSZGJX9pDbJnfxnmWTsoZ4F                                                NaN
# ...

# %%
# Get first value in the first row and first column. Replace order row and first column with value

# Get value in col 1 row 1
orders_dict.iat[1,0] = orders_dict.iat[0,0]


# Drop the first row
orders_dict_only_orders = orders_dict.drop(orders_dict.index[0])
orders_dict_only_orders
# Out:
#                                      MW_pM0pEch3dDoHZG0Q  \
# order  {'created_at': '2021-03-24T20:03:08.903Z', 'cu...
#
#                                      MW_pQf_FsTiUj8o47Hp  \
# order  {'created_at': '2021-03-24T20:03:28.569Z', 'cu...
#
#                                      MW_pTcdKVnoIblt0inx  \
# order  {'created_at': '2021-03-24T20:03:41.023Z', 'cu...
#
#                                      MW_pgsFWmAFqvBYNKGz  \
# order  {'created_at': '2021-03-24T20:04:39.151Z', 'cu...
#
#                                      MWbeV0FYiuufU2SNAxH  \
# order  {'created_at': '2021-03-25T04:34:57.288Z', 'cu...
#
#                                      MWdi97_Mo4ACk1d4w0s  \
# order  {'created_at': '2021-03-25T14:10:10.646Z', 'cu...
#
#                                      MWfkiau2GOEdj4F8RlM  \
# order  {'created_at': '2021-03-25T23:40:38.657Z', 'cu...
#
#                                      MWg6OXOqVdyJeToxZkE  \
# order  {'created_at': '2021-03-26T01:19:41.489Z', 'cu...
#
# ...

# %% [markdown]
# ### Flatten one account

# %%
# Conver json to a DataFrame
one_order_flattened = pd.json_normalize(orders_dict_only_orders.iat[0,0])

# %% [markdown]
# ### Create Master DataFrame

# %%
# Instantiate Blank Data Frame
# Store Columns in variable
master_df = pd.DataFrame()
cols = orders_dict_only_orders.columns

for single_account in cols:
    print(orders_dict_only_orders[single_account])
    
    # Flatten
    df = pd.json_normalize(orders_dict_only_orders[single_account])
    
    # Add Account column and fill the value
    df['account'] = single_account
    
    #Concat dataframes
    frames = [master_df, df]
    master_df = pd.concat(frames)
    
    
master_df
# Out:
# order    {'created_at': '2021-03-24T20:03:08.903Z', 'cu...
# Name: MW_pM0pEch3dDoHZG0Q, dtype: object
# order    {'created_at': '2021-03-24T20:03:28.569Z', 'cu...
# Name: MW_pQf_FsTiUj8o47Hp, dtype: object
# order    {'created_at': '2021-03-24T20:03:41.023Z', 'cu...
# Name: MW_pTcdKVnoIblt0inx, dtype: object
# order    {'created_at': '2021-03-24T20:04:39.151Z', 'cu...
# Name: MW_pgsFWmAFqvBYNKGz, dtype: object
# order    {'created_at': '2021-03-25T04:34:57.288Z', 'cu...
# Name: MWbeV0FYiuufU2SNAxH, dtype: object
# order    {'created_at': '2021-03-25T14:10:10.646Z', 'cu...
# Name: MWdi97_Mo4ACk1d4w0s, dtype: object
# order    {'created_at': '2021-03-25T23:40:38.657Z', 'cu...
# Name: MWfkiau2GOEdj4F8RlM, dtype: object
# order    {'created_at': '2021-03-26T01:19:41.489Z', 'cu...
# Name: MWg6OXOqVdyJeToxZkE, dtype: object
# order    {'created_at': '2021-03-26T01:39:07.563Z', 'cu...
# Name: MWgAqBsMj513GCEXhiN, dtype: object
# order    {'created_at': '2021-03-26T01:39:24.061Z', 'cu...
# ...

# %%
from pandas.io.json import json_normalize
json_normalize(order_ids)
# Out:
# <ipython-input-86-dcc3c3da59ea>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   json_normalize(order_ids)
#    orl6bgSZGJX9pDbJnfxnmWTsoZ4F.created_at  \
# 0                 2021-03-24T20:03:08.903Z
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# ...

# %% [markdown]
# ### Clean Data Frame

# %%
# Order Columns
columns_ordered = ['id', 'account', 'location_id', 'customer_id', 'created_at', 'updated_at', 'line_items',  'state',
       'version', 'net_amounts.discount_money.amount',
       'net_amounts.discount_money.currency',
       'net_amounts.service_charge_money.amount',
       'net_amounts.service_charge_money.currency',
       'net_amounts.tax_money.amount', 'net_amounts.tax_money.currency',
       'net_amounts.tip_money.amount', 'net_amounts.tip_money.currency',
       'net_amounts.total_money.amount', 'net_amounts.total_money.currency',
       'source.name', 'total_discount_money.amount',
       'total_discount_money.currency', 'total_money.amount',
       'total_money.currency', 'total_service_charge_money.amount',
       'total_service_charge_money.currency', 'total_tax_money.amount',
       'total_tax_money.currency', 'total_tip_money.amount',
       'total_tip_money.currency']

# %%
# Filter columns
filtered_columns = [x for x in columns_ordered if 'currency' not in x]
filtered_columns
# Out:
# ['id',
#  'account',
#  'location_id',
#  'customer_id',
#  'created_at',
#  'updated_at',
#  'line_items',
#  'state',
#  'version',
#  'net_amounts.discount_money.amount',
#  'net_amounts.service_charge_money.amount',
#  'net_amounts.tax_money.amount',
#  'net_amounts.tip_money.amount',
#  'net_amounts.total_money.amount',
#  'source.name',
#  'total_discount_money.amount',
#  'total_money.amount',
#  'total_service_charge_money.amount',
#  'total_tax_money.amount',
#  'total_tip_money.amount']

# %%
master_df_ordered_filtered = master_df.reindex(columns=filtered_columns)

# %%
master_df_ordered_filtered.columns
# Out:
# Index(['id', 'account', 'location_id', 'customer_id', 'created_at',
#        'updated_at', 'line_items', 'state', 'version',
#        'net_amounts.discount_money.amount',
#        'net_amounts.service_charge_money.amount',
#        'net_amounts.tax_money.amount', 'net_amounts.tip_money.amount',
#        'net_amounts.total_money.amount', 'source.name',
#        'total_discount_money.amount', 'total_money.amount',
#        'total_service_charge_money.amount', 'total_tax_money.amount',
#        'total_tip_money.amount'],
#       dtype='object')

# %% [markdown]
# ### Write Out

# %%
master_df_ordered_filtered.to_csv("C:\\Users\Snowbird\Documents\Joshua\Personal\Technical\GitHub\Firebase\orders.csv", index=False)

# %% [markdown]
# ### Analyze

# %%
master_df_ordered_filtered.describe()
# Out:
#        version  net_amounts.discount_money.amount  \
# count     24.0                               24.0
# mean       1.0                                0.0
# std        0.0                                0.0
# min        1.0                                0.0
# 25%        1.0                                0.0
# 50%        1.0                                0.0
# 75%        1.0                                0.0
# max        1.0                                0.0
#
#        net_amounts.service_charge_money.amount  net_amounts.tax_money.amount  \
# count                                     24.0                          24.0
# mean                                       0.0                           0.0
# std                                        0.0                           0.0
# min                                        0.0                           0.0
# 25%                                        0.0                           0.0
# ...
